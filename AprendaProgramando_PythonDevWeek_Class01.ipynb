# %% [markdown]
# #### SEMANA DO PROGRAMADOR PYTHON - *Aprenda Programando* - Jefferson Santos 1° Aula 05-10-2020

# %%
# Imprimindo olá mundo para o usuário
print("Hello World!")  # imprimindo olá mundo
# Out:
# Hello World!

# %%
print("Bem vindo a semana do programador Python")
# Out:
# Bem vindo a semana do programador Python

# %%
# Declarando variável tipo string
nome = "Wagner"

# %%
print(nome)
# Out:
# Wagner

# %%
1_nome = 'Wagner'

# Apresenta erro por começar a variavel com numero
# Out:
#   File "<ipython-input-7-ee0dec90a62b>", line 1
#     1_nome = 'Wagner'
#      ^
# SyntaxError: invalid token

# %%
nome_1 = 'Wagner Oliveira'

# %%
print(nome_1)
# Out:
# Wagner Oliveira

# %%
nome_completo = 'Wagner Oliveira'

# %%
print(nome_completo)
# Out:
# Wagner Oliveira

# %%
ano = 2020

# %%
# Checando o tipo da variável
type(nome_completo)
# Out:
# str

# %%
type(ano)
# Out:
# int

# %%
endereco_completo = 'rua 2, 100'

# %% [markdown]
# STRINGS

# %%
print(nome_completo)
# Out:
# Wagner Oliveira

# %%
print(nome_completo.upper())
# Out:
# WAGNER OLIVEIRA

# %%
print(nome_completo)
# Out:
# Wagner Oliveira

# %%
print(nome_completo.title())
# Out:
# Wagner Oliveira

# %%
nome_carro = 'COROLLA'

# %%
nome_carro
# Out:
# 'COROLLA'

# %%
print(nome_carro.lower())
# Out:
# corolla

# %% [markdown]
# NÚMEROS

# %%
idade = 20

# %%
numero_casa = 145

# %%
type(idade)
# Out:
# int

# %%
type(numero_casa)
# Out:
# int

# %%
preco = 1.54

# %%
type(preco)
# Out:
# float

# %%
num_1 = 20

# %%
num_2 = 10

# %%
print(num_1 + num_2)
# Out:
# 30

# %%
soma = num_1 + num_2

# %%
print(soma)
# Out:
# 30

# %%
subt = num_1 - num_2

# %%
subt
# Out:
# 10

# %%
preco_arroz = 5.23

# %%
preco_feijao = 8.29

# %%
soma_comida = preco_arroz + preco_feijao

# %%
print(soma_comida)
# Out:
# 13.52

# %%
preco_arroz = 3.20

# %%
preco_arroz
# Out:
# 3.2
