# %% [markdown]
# #### SEMANA DO PROGRAMADOR PYTHON - *Aprenda Programando* - Jefferson Santos 2° Aula 07-10-2020

# %% [markdown]
# F-STRING

# %%
primeiro_nome = 'Wagner'

# %%
ultimo_nome = 'Oliveira'

# %%
print(primeiro_nome, ultimo_nome)
# Out:
# Wagner Oliveira

# %%
print(f"O nome do cliente é {primeiro_nome.title()} {ultimo_nome.title()}...")
# Out:
# O nome do cliente é Wagner Oliveira...

# %% [markdown]
# TUPLAS, LISTAS E DICIONÁRIOS

# %%
produto = ('arroz', 'alimento')

# %%
print(produto)
# Out:
# ('arroz', 'alimento')

# %%
produtos = ['pão', 'manteiga', 'sal']

# %%
print(produtos)
# Out:
# ['pão', 'manteiga', 'sal']

# %%
produtos.append('queijo')

# %%
produtos
# Out:
# ['pão', 'manteiga', 'sal', 'queijo']

# %%
item_removido = produtos.pop()

# %%
item_removido
# Out:
# 'queijo'

# %%
produtos
# Out:
# ['pão', 'manteiga', 'sal']

# %%
carro = {
    'nome': 'corolla',
    'ano': 2015,
    'motor': 2.0
}

# %%
carro
# Out:
# {'ano': 2015, 'motor': 2.0, 'nome': 'corolla'}

# %%
print(carro['motor'])
# Out:
# 2.0

# %% [markdown]
# Tuplas = ()
# Listas = []
# Dicionários = {}

# %%
casa = ('rua 2, 100', 1970)
#                0      1

# %%
print(casa[0])
# Out:
# rua 2, 100

# %%
print(casa[1])
# Out:
# 1970

# %%
print(casa[2])
#mostra erro porque não foi definido valor
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-32-35d056fc32fd> in <module>()
# ----> 1 print(casa[2])
#
# IndexError: tuple index out of range

# %%
carros = ['fiesta', 'corolla', 'civic', 'gol', 'palio', 'fusion']
#              0         1         2       3        4        5

# %%
carros
# Out:
# ['fiesta', 'corolla', 'civic', 'gol', 'palio', 'fusion']

# %%
carros[-1]
# Out:
# 'fusion'

# %%
carros.append('sorento')

# %%
carros
# Out:
# ['fiesta', 'corolla', 'civic', 'gol', 'palio', 'fusion', 'sorento']

# %%
carros.pop()
# Out:
# 'sorento'

# %%
carros
# Out:
# ['fiesta', 'corolla', 'civic', 'gol', 'palio', 'fusion']

# %%
carros.append('fiesta')

# %%
carros
# Out:
# ['fiesta', 'corolla', 'civic', 'gol', 'palio', 'fusion', 'fiesta']

# %%
cantor = {
    'nome': 'Roberto Carlos',
    'ano_nascimento': 1950,
    'cidade': 'Curitiba'
}

# %%
cantor
# Out:
# {'ano_nascimento': 1950, 'cidade': 'Curitiba', 'nome': 'Roberto Carlos'}

# %%
cantor['nome'].lower()
# Out:
# 'roberto carlos'

# %%
cantor['estilo'] = 'MPB'

# %%
cantor
# Out:
# {'ano_nascimento': 1950,
#  'cidade': 'Curitiba',
#  'estilo': 'MPB',
#  'nome': 'Roberto Carlos'}

# %%
cantor['estilo']
# Out:
# 'MPB'

# %%
cantor['cidade'].pop()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-49-d5b8742c2ec4> in <module>()
# ----> 1 cantor['cidade'].pop()
#
# AttributeError: 'str' object has no attribute 'pop'

# %%
cantor.pop('cidade', 'chave cidade não encontrada!')
# Out:
# 'Curitiba'

# %%
cantor
# Out:
# {'ano_nascimento': 1950, 'estilo': 'MPB', 'nome': 'Roberto Carlos'}

# %%
cantor.pop('cidade', 'chave cidade não encontrada!')
# Out:
# 'chave cidade não encontrada!'

# %%
cantor.keys()
# Out:
# dict_keys(['nome', 'ano_nascimento', 'estilo'])

# %%
cantor.values()
# Out:
# dict_values(['Roberto Carlos', 1950, 'MPB'])

# %% [markdown]
# BOOLEAN

# %%
run = False

# %%
print(run)
# Out:
# False

# %%
print(int(run))
# Out:
# 0

# %%
run = True

# %%
print(run)
# Out:
# True

# %%
print(int(run))
# Out:
# 1

# %% [markdown]
# IF STATEMENT

# %%
20 == 10
# Out:
# False

# %%
10 == 10
# Out:
# True

# %%
2 > 3
# Out:
# False

# %%
2 < 3
# Out:
# True

# %%
nome = 'jefferson santos'
idade = 66

# %%
if idade > 20:  # Essa declaração é VERDADEIRA
    print(nome)
else:
    print(f"A idade do usuário é {idade}.")
# Out:
# jefferson santos

# %%
if idade <= 2: 
    print("Passagem grátis!")
elif idade <= 12:
    print("Pasagem tem 75% de desconto")
elif idade <= 65:
    print("Passagem sem desconto!")
else:
    print("Passagem com 25% de desconto")
# Out:
# Passagem com 25% de desconto

# %% [markdown]
# FOR LOOP

# %%
produtos = ['queijo', 'arroz', 'macarrão', 'azeite', 'ovo', 'manteiga']
 #             0          1      2           3

# %%
produtos
# Out:
# ['queijo', 'arroz', 'macarrão', 'azeite', 'ovo', 'manteiga']

# %%
for produto in produtos:
    print(f"O produto {produto} tem em estoque!")
# Out:
# O produto queijo tem em estoque!
# O produto arroz tem em estoque!
# O produto macarrão tem em estoque!
# O produto azeite tem em estoque!
# O produto ovo tem em estoque!
# O produto manteiga tem em estoque!

# %%
for numero in range(1, 11):
    print(numero / 2.47653)
# Out:
# 0.4037907879169645
# 0.807581575833929
# 1.2113723637508935
# 1.615163151667858
# 2.0189539395848226
# 2.422744727501787
# 2.8265355154187515
# 3.230326303335716
# 3.6341170912526803
# 4.037907879169645

# %%
def somar_dois_numeros(num1, num2):
    return num1 + num2

# %%
numero_1 = 5
numero_2 = 13

# %%
print(numero_1 + numero_2)
# Out:
# 18

# %%
print(somar_dois_numeros(numero_1, numero_2))
# Out:
# 18

# %%
print(somar_dois_numeros(25, 1))
# Out:
# 26

# %%
def saudacao(nome_usuario):
    print(f"{nome_usuario}, seja bem-vindo(a)!")

# %%
saudacao('Pedro')
# Out:
# Pedro, seja bem-vindo(a)!

# %%
saudacao('Maria')
# Out:
# Maria, seja bem-vindo(a)!

# %%
usuario = 'João'

# %%
saudacao(usuario)
# Out:
# João, seja bem-vindo(a)!
