# %% [markdown]
# ### Atividades da semana programador python APRENDA PROGRAMANDO  => Jeferson Santos   05-10-2020

# %% [markdown]
# # **Primeira atividade**

# %%
# Cria a sua conta no google
email = "srwayne00@gmail.com"

# %%
# Acesse google colab 
site = "https://colab.research.google.com/drive/1jve920hH8ooLd_leEcG-miJQp17S023M#scrollTo=BeykHn-Kr95G"

# %%
# Crie o seu primeiro programa escrevendo "Olá mundo!" com a função print 
print ("Hello World!");       # imprime o texto entre aspas
# Out:
# Hello World!

# %%
# Use a função print() para mostrar seu nome completo na tela 
nome = "Wagner Oliveira"      # atribuição do valor Wagner Oliveira a variavel nome
print(nome)
# Out:
# Wagner Oliveira

# %% [markdown]
# # **Segunda atividade**

# %%
# Crie uma variavel chamada endereco e atribua o seu valor com o seu endereco residencial
endereco = "Edilson Godoy Martins, 126"

# %%
# Mostre na tela o conteudo dessa variavel usando a função print().
print(endereco)
# Out:
# Edilson Godoy Martins, 126

# %%
# Altere o valor dessa variavel para o endereço do seu local de trabalho
endereco = "Av Tiradentes, 2065"

# %%
# Mostre na tela o conteudo dessa variavel com o novo valor usando a função print().
print(endereco)
# Out:
# Edilson Godoy Martins, 126

# %% [markdown]
# # **Terceira atividade**

# %%
# Crie duas variaveis do tipo string (nome_produto e categoria_produto) e de um valor a cada uma
nome_produto = "Python Book" 
categoria_produto = "Python Development"

# %%
# Usando a função type(). confirme que elas são do tipo str e em seguida mostre ambas usando a função print().
print(categoria_produto)
type(categoria_produto)
# Out:
# Python Development
# str

# %%
print(nome_produto)
type(nome_produto)
# Out:
# Python Book
# str

# %%
# Usando a função upper(). lower().title().
print(nome_produto.upper())
print(nome_produto.lower())
print(nome_produto.title())

# %%
print(categoria_produto.upper())
print(categoria_produto.lower())
print(categoria_produto.title())

# %% [markdown]
# # **Quarta atividade**

# %%
# Crie duas variaveis do tipo numero(preco_produto e ano_fabricacao) e de um valor a cada uma
preco_produto = 5.000
ano_fabricacao = 2020

# %%
# Usando a função type(). confirme que elas são do tipo int ou float e mostre ambas usando o print().
preco_produto = 5.000
print(preco_produto)
type(preco_produto)
# Out:
# 5.0
# float

# %%
ano_fabricacao = 2020
print(ano_fabricacao)
type(ano_fabricacao)
# Out:
# 2020
# int

# %%
# Acima de cada linha de codigo adicone um comentario explicando o seu significado
#Feito :)
